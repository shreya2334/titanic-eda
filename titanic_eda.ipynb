# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'C:\Users\shrey\OneDrive\Desktop\shreya\titanic_eda\Titanic-Dataset.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
print(df.columns.tolist())
# Out:
# ['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked']

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
print(df.count())
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# dtype: int64

# %%
df.shape
# Out:
# (891, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
print(df.isnull().sum()) #counts missing values
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
print(df.duplicated().sum()) #checks duplicates
# Out:
# 0

# %%
print(df.nunique())
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %%
df['Age'] = df['Age'].fillna(df['Age'].median())
print(df['Age'])

df['Embarked'] = df['Embarked'].fillna(df['Embarked'].mode()[0])
print(df['Embarked'].isnull().sum())
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888    28.0
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64
# 0

# %%
# df['Age'] = df.fillna({'Age': df['Age'].median()}, inplace = True)

# %%
# print(df['Age'].to_string())

# %%
df.drop('Cabin', axis = 1, inplace = True)

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Embarked'],
#       dtype='object')

# %% [markdown]
# ### Univariate analysis

# %%
sns.countplot(data = df, x = 'Sex')
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
sns.countplot(data = df, x = 'Survived')
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sns.countplot(data = df, x = 'Pclass')
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
sns.countplot(data = df, x = 'Embarked')
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %%
sns.histplot(df['Age'], kde = True, bins = 30)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.histplot(df['Fare'], kde = True, bins = 30, color = 'pink', edgecolor = 'red')
# Out:
# <Axes: xlabel='Fare', ylabel='Count'>

# %%
sns.histplot(df['SibSp'], kde = True, bins = 30, color = 'cyan', edgecolor = 'skyblue')
# Out:
# <Axes: xlabel='SibSp', ylabel='Count'>

# %%
sns.histplot(df['Parch'], kde = True, bins = 30, color = 'magenta', edgecolor = 'purple')
# Out:
# <Axes: xlabel='Parch', ylabel='Count'>

# %%
sns.countplot(data = df, x = 'SibSp')
# Out:
# <Axes: xlabel='SibSp', ylabel='count'>

# %%
sns.countplot(data = df, x = 'Parch')
# Out:
# <Axes: xlabel='Parch', ylabel='count'>

# %% [markdown]
# ### Bivariate analysis

# %%
sns.countplot(data = df, x = 'Sex', hue = 'Survived')
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
sns.barplot(x = 'Pclass', y = 'Survived', data = df)
plt.title('Survival rate by passenger class')
plt.show()

# %%
sns.countplot(data = df, x = 'Pclass', hue = 'Survived')
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
sns.countplot(data = df, x = 'Embarked', hue = 'Survived')
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %%
sns.boxplot(x = 'Age', y = 'Survived', data = df)
# Out:
# <Axes: xlabel='Age', ylabel='Survived'>

# %%
df['AgeGroup'] = pd.cut(df['Age'], bins = [0, 12, 18, 40, 60, 80],
                       labels = ['Child', 'Teen', 'Adult', 'MiddleAge', 'Senior'])
sns.countplot(data = df, x = 'AgeGroup', hue = 'Survived')
# Out:
# <Axes: xlabel='AgeGroup', ylabel='count'>

# %%
df['FamilySize'] = df['SibSp'] + df['Parch'] + 1

# %%
sns.countplot(data = df, x = 'FamilySize', hue = 'Survived')
# Out:
# <Axes: xlabel='FamilySize', ylabel='count'>

# %%
sns.countplot(data = df, x = 'Fare', hue = 'Survived')
# Out:
# <Axes: xlabel='Fare', ylabel='count'>

# %%
sns.boxplot(x = 'Survived', y = 'Fare', data = df)
# Out:
# <Axes: xlabel='Survived', ylabel='Fare'>

# %%
sns.countplot(data = df, x = 'Embarked', hue = 'Survived')
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %%
sns.countplot(data = df, x = 'SibSp', hue = 'Survived')
# Out:
# <Axes: xlabel='SibSp', ylabel='count'>

# %%
sns.countplot(data = df, x = 'Parch', hue = 'Survived')
# Out:
# <Axes: xlabel='Parch', ylabel='count'>

# %%
sns.heatmap(df.corr(numeric_only = True), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# ### Feature Engineering

# %%
df['Title'] = df['Name'].str.extract(' ([A-Za-z]+\.)', expand = False)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\.'
# <>:1: SyntaxWarning: invalid escape sequence '\.'
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4760\2243016323.py:1: SyntaxWarning: invalid escape sequence '\.'
#   df['Title'] = df['Name'].str.extract(' ([A-Za-z]+\.)', expand = False)

# %%
rare_titles = ['Lady', 'Countess', 'Capt', 'Col', 'Don', 'Dr', 'Major', 'Rev', 'Sir', 'Jonkheer', 'Dona']
df['Title'] = df['Title'].replace(rare_titles, 'Rare')
df['Title'] = df['Title'].replace({'Mlle' : 'Miss', 'Ms' : 'Miss', 'Mme' : 'Mrs'})

# %%
df['FareGroup'] = pd.cut(df['Fare'], 4, labels = ['Low', 'Medium', 'High', 'Very High'])

# %%
df['IsAlone'] = (df['FamilySize'] == 1).astype(bool)

# %%
from sklearn.preprocessing import LabelEncoder

cols = ['Sex', 'Embarked', 'Title', 'AgeGroup', 'FareGroup']
le = LabelEncoder()

for col in cols:
    df[col] = le.fit_transform(df[col].astype(str))

# %%
df.drop(['Name', 'Ticket'], axis = 1, inplace = True)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked  \
# 0            1         0       3    1  22.0      1      0   7.2500         2
# 1            2         1       1    0  38.0      1      0  71.2833         0
# 2            3         1       3    0  26.0      0      0   7.9250         2
# 3            4         1       1    0  35.0      1      0  53.1000         2
# 4            5         0       3    1  35.0      0      0   8.0500         2
#
#    AgeGroup  FamilySize  Title  FareGroup  IsAlone
# 0         0           2     12          1    False
# 1         0           2     13          1    False
# 2         0           1      9          1     True
# 3         0           2     13          1    False
# 4         0           1     12          1     True

# %% [markdown]
# ## Insight Summary

# %% [markdown]
# - **Sex** → *Female* passengers had a significantly **higher** survival rate compared to males.
# - **Fare** → Survival *increased* with **higher** fare, indicating that wealthier passengers had better access to safety.
# - **Pclass** → *1st-class* passengers survived the **most**, while 3rd-class had the lowest survival rate.
# - **Age** → After grouping ages into categories, *children* showed the **highest** survival, supporting the "women and children first" pattern.
# - **FamilySize** → Most passengers were travelling *alone*, and their survival rate was **lower** compared to those travelling with small families.
# - **Engineered Features** → Added `Title`, `FareGroup`, and `IsAlone`, which help differentiate social status, wealth categories, and travel type. These were encoded using `LabelEncoder` for model readiness.
